# %% [markdown]
# ## Class definitions and util functions

# %%
# %pip install dataclasses

from dataclasses import dataclass
from typing import Literal, Any
from collections import defaultdict


@dataclass
class Feria:
    cod_comuna: str
    comuna: str
    dias: list[int]
    cantidad_puestos: int


@dataclass
class Producto:
    id: int
    nombre: str
    meses_siembra: list[int]
    meses_venta: list[int]
    dias_cosecha: float
    unidad: Literal["unidades", "kilos"]
    unit_ha: float
    volumen_feriante: float
    volumen_un_consumidor: float
    prob_consumir: float
    costo_ha: float
    prob_compra_feriante: float
    oc: tuple[float, float, float]
    sequias: tuple[float, float, float]
    heladas: tuple[float, float, float]
    plagas: tuple[float, float, float]
    precios_mes: list[float]
    precio_consumidor: float


@dataclass
class Solution:
    items: list[int]
    data: list[Any]

    def get_partitions(self) -> dict[int, list[Any]]:
        partitions = defaultdict(list)
        for idx, item in enumerate(self.items):
            partitions[item].append(self.data[idx])
        return partitions

    def copy(self) -> 'Solution':
        return Solution(items=self.items.copy(), data=self.data.copy())
# Out:
# Requirement already satisfied: dataclasses in /home/manacho/anaconda3/envs/tesis-transformers/lib/python3.11/site-packages (0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json


def read_ferias(file_dir: str) -> list[Feria]:
    with open(file_dir, 'r') as file:
        data = json.load(file)
    ferias = [Feria(**feria) for feria in data]
    return ferias


def read_productos(file_dir: str) -> list[Producto]:
    with open(file_dir, 'r') as file:
        data = json.load(file)
    items = [{"unit_ha" if key == "unit/ha" else key: val for key, val in item.items()}
             for item in data]
    productos = [Producto(**item) for item in items]
    return productos

# %% [markdown]
# ## Main algorithm and helper functions

# %% [markdown]
# ### Main implementation of Simulated Annealing

# %%
from typing import Any, Callable
from math import sqrt
import random
import math


def simulated_annealing_partitioning(
    items: list[Any],
    n: int,
    f: Callable[..., Any],
    find_neighbour: Callable[..., Any],
    init_temp: float = 1_000,
    temp_threshold: float = 1e-3,
    cooling_rate: float = 0.99,
    debug: bool = False,
    **kwargs,
) -> tuple[Solution, float, list[float], list[float]]:
    """
    Implementación de Simulated Annealing para maximizar una función objetivo dada.
    Params:
        - items: elementos a particionar
        - n: número de particiones a generar
        - f: función objetivo a ser maximizada.
        - find_neighbour: función para encontrar el siguiente vecino a evaluar
        - temp_threshold: umbral para enfriamiento del recocido
        - cooling_rate: tasa de enfriamiento. Reduce geométricamente la temperatura.
    """
    best_score_history = []
    current_score_history = []

    # Generamos solución inicial de forma aleatoria
    initial_assignments = [random.randint(0, n - 1) for _ in items]
    sol = Solution(items=initial_assignments, data=items)
    sol_score = f(sol, **kwargs)
    best_score = sol_score
    best_sol = sol.copy()
    temp = init_temp

    while temp > temp_threshold:
        neighbour = find_neighbour(sol, f, **kwargs)
        new_score = f(neighbour, **kwargs)
        delta = new_score - sol_score

        if delta > 0 or random.uniform(0, 1) < math.exp(delta / temp):
            sol = neighbour
            sol_score = new_score

            if sol_score > best_score:
                best_score = sol_score
                best_sol = sol.copy()

        temp *= cooling_rate
        best_score_history.append(best_score)
        current_score_history.append(sol_score)

        if debug:
            print(f"Best score: {best_score}, Current score: {sol_score}, Temperature: {temp}")

    return best_sol, best_score, best_score_history, current_score_history

# %% [markdown]
# ### Neighbourhood search functions

# %%
def find_next_best_neighbour(
    sol: Solution, f: Callable[..., Any], op: Callable[..., Any], r: int = 1, n_iter: int = 100, **kwargs
) -> Solution:
    """
    Función que implementa procedimiento para encontrar el siguiente mejor vecino.
    Params:
        - sol: Solución que corresponde al punto de inicio de la búsqueda
        - f: Función objetivo para evaluar la calidad de la solución
        - r: Cantidad de veces que se aplica el operador entre vecinos evaluados. Un valor más grande significa que los vecinos evaluados serán más distintos entre sí, mientras que un valor más pequeño evaluará vecinos más cercanos o similares.
        - n_iter: Cantidad máxima de iteraciones hasta detener la búsqueda
        - op: Operador para explorar la vecindad
    """
    score = f(sol, **kwargs)
    best_sol = sol
    best_score = score

    for _ in range(n_iter):
        new_sol = sol.copy()
        for _ in range(r):
            new_sol = op(new_sol, **kwargs)
        new_score = f(new_sol, **kwargs)
        if new_score > best_score:
            return new_sol
    return best_sol


def adaptive_next_neighbour(
    sol: Solution, f: Callable, g: Callable[list, list], r: int = 1, **kwargs
) -> Solution:
    """
    Función que encuentra el siguiente vecino en función de la distribución actual de 
    carga de cómputo. Usa una función greedy g() para determinar la carga relativa de cada
    partición, para luego intercambiar r elementos de la partición con más carga con la 
    con menor carga.
    """
    new_sol = sol.copy()

    for _ in range(r):
        partitions = new_sol.get_partitions()
        partitions_score = {k: g(items) for k, items in partitions.items()}
        min_part = min(partitions_score, key=partitions_score.get)
        max_part = max(partitions_score, key=partitions_score.get)

        if not partitions[min_part] or not partitions[max_part]:
            continue

        item_min = random.choice(partitions[min_part])
        item_max = random.choice(partitions[max_part])

        idx_min = new_sol.data.index(item_min)
        idx_max = new_sol.data.index(item_max)

        # Intercambiamos los asignamientos
        new_sol.items[idx_min], new_sol.items[idx_max] = new_sol.items[idx_max], new_sol.items[idx_min]

    return new_sol

def move_operator(sol: Solution) -> Solution:
    """
    Mueve un elemento a una partición diferente.
    """
    new_sol = copy.deepcopy(sol)
    idx = random.randint(0, len(new_sol.items) - 1)
    new_partition = random.randint(0, max(new_sol.items))
    new_sol.items[idx] = new_partition
    return new_sol

def shaker_operator(
    sol: Solution
) -> Solution:
    """
    Intercambia dos elementos al azar de una solución
    """
    new_sol = sol.copy()
    # Elegimos dos índices al azar
    idx1, idx2 = random.sample(range(len(new_sol.items)), 2)
    # Intercambiamos los valores
    new_sol.items[idx1], new_sol.items[idx2] = new_sol.items[idx2], new_sol.items[idx1]
    return new_sol

# %% [markdown]
# ### Product objective functions

# %%
def productos_naive_objective_function(sol: Solution, **_) -> float:
    """
    Función similar a lo implementado en la primera versión del particionador.
    Encuentra un centroide que representa la distribución ideal por mes del año y 
    calcula la distancia con respecto a ese vector.
    """

    # Obtenemos las particiones
    num_items = len(sol.data)
    centroid = [0] * 12

    # Calculamos el centroide
    for prod in sol.data:
        for mes in prod.meses_venta:
            centroid[mes] += 1
    centroid = [x / num_items for x in centroid]

    diff = 0.0
    partitions = sol.get_partitions()
    for partition in partitions.values():
        vector = [0] * 12
        for prod in partition:
            for mes in prod.meses_venta:
                vector[mes] += 1
        vector = [x / num_items for x in vector]
        diff += sum(abs(x - y) for x, y in zip(vector, centroid))

    return -diff


def productos_weighted_naive_objective_function(sol: Solution, **_) -> float:
    """
    Similar a la versión anterior, pero pondera por la probabilidad de compra
    de feriante - que debería ser un valor proxy para la cantidad de trabajo asociado a 
    ese producto.
    """

    # Obtenemos las particiones
    partitions = sol.get_partitions()

    # Calculamos centroide inicial
    centroid = [0] * 12
    for prod in sol.data:
        for mes in prod.meses_venta:
            centroid[mes] += prod.prob_compra_feriante

    # Calculamos el vector para cada partición y calculamos la diferencia
    diff = 0.0
    for partition in partitions.values():
        vector = [
            prod.prob_compra_feriante for mes in prod.meses_venta for prod in partition]
        diff += sum(map(lambda x, y: (x - y)**2, vector, centroid))
    return -sqrt(diff)


def productos_penalized_weighted_obj_function(sol: Solution, penalty: float = 0.1, **kwargs) -> float:
    """
    Esta implementación abandona la idea de un centroide ideal.
    Más bien, se intenta maximizar la cantidad de cómputo de cada partición.
    Además, si una partición no tiene cómputo para algún mes de la simulación, 
    se le penaliza.
    """

    partitions = sol.get_partitions()
    total_score = 0.0

    for partition in partitions.values():
        months = [0.0] * 12
        for prod in partition:
            for mes in prod.meses_venta:
                months[mes] += prod.prob_compra_feriante
        # Penalizamos los meses sin actividad
        partition_score = sum(month if month > 0 else -penalty for month in months)
        total_score += partition_score

    return total_score


def producto_partition_greedy_function(partition: list[Producto], penalty: float = 0.1) -> float:
    months = [0.0] * 12
    score = 0.0
    for prod in partition:
        for active_month in prod.meses_venta:
            months[active_month] += prod.prob_compra_feriante
    for month in months:
        score += month if month else -penalty

    return score

# %% [markdown]
# ### Ferias objective functions

# %%
def feria_penalized_objective_function(sol: Solution, penalty: float = 200, **_):
    partitions = sol.get_partitions()
    scores = []
    # Recorremos las particiones y obtenemos sus puntajes respectivos
    for partition in partitions.values():
        score = 0.0
        vector = [0.0] * 7
        for feria in partition:
            for dia in feria.dias:
                vector[dia] += feria.cantidad_puestos
        for dia in vector:
            score += dia if dia else -penalty
        scores.append(score)

    return min(scores)

# %% [markdown]
# ## Executions and plotting

# %%
ferias = read_ferias('../inputs/ferias.json')

productos = read_productos('../inputs/prods.json')
# Registramos las funciones objetivo a evaluar
obj_functions = [
    ('naive', productos_naive_objective_function),
    ('weighted', productos_weighted_naive_objective_function),
    ('penalized_weighted', productos_penalized_weighted_obj_function),
]

# %%
eval_data = {}

for name, func in obj_functions:
    sol, score, best_score_history, current_score_history = simulated_annealing_partitioning(
        items=productos,
        n=8,
        f=productos_weighted_naive_objective_function,
        find_neighbour=find_next_best_neighbour,
        op=shaker_operator,
        r=1,
        cooling_rate=0.999
    )

    eval_data.update({name: {"best_score": score, "best_score_history": best_score_history,
                     "solution": sol, "current_score_history": current_score_history}})

# %%
import matplotlib.pyplot as plt


fig, axs = plt.subplots(len(eval_data), 1, figsize=(8, len(eval_data) * 4))

for i, (name, data) in enumerate(eval_data.items()):
    x_vals = list(range(1, len(data["best_score_history"]) + 1))
    best_y_vals = data["best_score_history"]
    current_y_vals = data["current_score_history"]

    axs[i].plot(x_vals, best_y_vals, label="Best score")
    axs[i].plot(x_vals, current_y_vals, label="Current score", color="grey")

    min_best, max_best = min(best_y_vals), max(best_y_vals)
    min_curr, max_curr = min(current_y_vals), max(current_y_vals)

    axs[i].annotate(f"Min: {min_best}", xy=(best_y_vals.index(min_best), min_best),
                    xytext=(-15, 10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
    axs[i].annotate(f"Max: {max_best}", xy=(best_y_vals.index(max_best), max_best),
                    xytext=(-15, 10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
    # axs[i].annotate(f"Min: {min_curr}", xy=(current_y_vals.index(min_curr), min_curr), xytext=(-15,10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
    # axs[i].annotate(f"Min: {max_curr}", xy=(current_y_vals.index(max_curr), max_curr), xytext=(-15,10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))

    # Set title and legend
    axs[i].set_title(name)
    axs[i].legend()

# Show the figure
plt.tight_layout()
plt.show()

# %%
eval_data = {}

for name, func in obj_functions:
    sol, score, best_score_history, current_score_history = simulated_annealing_partitioning(
        items=productos,
        n=8,
        f=productos_weighted_naive_objective_function,
        find_neighbour=adaptive_next_neighbour,
        op=shaker_operator,
        r=1,
        cooling_rate=0.999,
        g=producto_partition_greedy_function,
    )

    eval_data.update({name: {"best_score": score, "best_score_history": best_score_history,
                     "solution": sol, "current_score_history": current_score_history}})

# %%
fig, axs = plt.subplots(len(eval_data), 1, figsize=(8, len(eval_data) * 4))

for i, (name, data) in enumerate(eval_data.items()):
    x_vals = list(range(1, len(data["best_score_history"]) + 1))
    best_y_vals = data["best_score_history"]
    current_y_vals = data["current_score_history"]

    axs[i].plot(x_vals, best_y_vals, label="Best score")
    axs[i].plot(x_vals, current_y_vals, label="Current score", color="grey")

    min_best, max_best = min(best_y_vals), max(best_y_vals)
    min_curr, max_curr = min(current_y_vals), max(current_y_vals)

    axs[i].annotate(f"Min: {min_best}", xy=(best_y_vals.index(min_best), min_best),
                    xytext=(-15, 10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
    axs[i].annotate(f"Max: {max_best}", xy=(best_y_vals.index(max_best), max_best),
                    xytext=(-15, 10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
    # axs[i].annotate(f"Min: {min_curr}", xy=(current_y_vals.index(min_curr), min_curr), xytext=(-15,10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
    # axs[i].annotate(f"Min: {max_curr}", xy=(current_y_vals.index(max_curr), max_curr), xytext=(-15,10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))

    # Set title and legend
    axs[i].set_title(name)
    axs[i].legend()

# Show the figure
plt.tight_layout()
plt.show()

# %%
sol, score, best_score_history, current_score_history = simulated_annealing_partitioning(
    items=ferias,
    n=8,
    f=feria_penalized_objective_function,
    find_neighbour=find_next_best_neighbour,
    op=shaker_operator,
    r=1,
    cooling_rate=0.99,
    debug=True
)


# Create a figure and axis using plt.subplots()
fig, ax = plt.subplots()

x_vals = list(range(1, len(best_score_history) + 1))
best_y_vals = best_score_history
current_y_vals = current_score_history
ax.plot(x_vals, best_y_vals, label="Best score")
ax.plot(x_vals, current_score_history, label="Current score", color="grey")


min_best, max_best = min(best_y_vals), max(best_y_vals)
min_curr, max_curr = min(current_y_vals), max(current_y_vals)

ax.annotate(f"Min: {min_best}", xy=(best_y_vals.index(min_best), min_best),
            xytext=(-15, 10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))
ax.annotate(f"Max: {max_best}", xy=(best_y_vals.index(max_best), max_best),
            xytext=(-15, 10), textcoords="offset points", arrowprops=dict(arrowstyle='->'))

ax.legend()

# Show the figure
plt.tight_layout()
plt.show()
# Out:
# Best score: 1943.0, Current score: 1943.0, Temperature: 990.0
# Best score: 1945.0, Current score: 1945.0, Temperature: 980.1
# Best score: 1971.0, Current score: 1971.0, Temperature: 970.299
# Best score: 1992.0, Current score: 1992.0, Temperature: 960.59601
# Best score: 2044.0, Current score: 2044.0, Temperature: 950.9900498999999
# Best score: 2070.0, Current score: 2070.0, Temperature: 941.480149401
# Best score: 2077.0, Current score: 2077.0, Temperature: 932.0653479069899
# Best score: 2086.0, Current score: 2086.0, Temperature: 922.74469442792
# Best score: 2191.0, Current score: 2191.0, Temperature: 913.5172474836407
# Best score: 2206.0, Current score: 2206.0, Temperature: 904.3820750088043
# Best score: 2212.0, Current score: 2212.0, Temperature: 895.3382542587163
# Best score: 2234.0, Current score: 2234.0, Temperature: 886.3848717161292
# Best score: 2234.0, Current score: 2234.0, Temperature: 877.5210229989679
# Best score: 2234.0, Current score: 2234.0, Temperature: 868.7458127689781
# Best score: 2234.0, Current score: 2234.0, Temperature: 860.0583546412884
# Best score: 2234.0, Current score: 2234.0, Temperature: 851.4577710948755
# Best score: 2234.0, Current score: 2234.0, Temperature: 842.9431933839268
# Best score: 2234.0, Current score: 2234.0, Temperature: 834.5137614500875
# Best score: 2234.0, Current score: 2234.0, Temperature: 826.1686238355866
# Best score: 2234.0, Current score: 2234.0, Temperature: 817.9069375972307
# Best score: 2234.0, Current score: 2234.0, Temperature: 809.7278682212584
# Best score: 2234.0, Current score: 2234.0, Temperature: 801.6305895390458
# Best score: 2234.0, Current score: 2234.0, Temperature: 793.6142836436553
# Best score: 2234.0, Current score: 2234.0, Temperature: 785.6781408072187
# Best score: 2234.0, Current score: 2234.0, Temperature: 777.8213593991466
# Best score: 2234.0, Current score: 2234.0, Temperature: 770.0431458051551
# Best score: 2234.0, Current score: 2234.0, Temperature: 762.3427143471035
# Best score: 2234.0, Current score: 2234.0, Temperature: 754.7192872036325
# Best score: 2234.0, Current score: 2234.0, Temperature: 747.1720943315961
# Best score: 2234.0, Current score: 2234.0, Temperature: 739.7003733882801
# Best score: 2234.0, Current score: 2234.0, Temperature: 732.3033696543973
# Best score: 2234.0, Current score: 2234.0, Temperature: 724.9803359578533
# Best score: 2234.0, Current score: 2234.0, Temperature: 717.7305325982747
# Best score: 2234.0, Current score: 2234.0, Temperature: 710.553227272292
# Best score: 2234.0, Current score: 2234.0, Temperature: 703.4476949995691
# Best score: 2234.0, Current score: 2234.0, Temperature: 696.4132180495734
# Best score: 2234.0, Current score: 2234.0, Temperature: 689.4490858690776
# Best score: 2234.0, Current score: 2234.0, Temperature: 682.5545950103868
# Best score: 2234.0, Current score: 2234.0, Temperature: 675.7290490602829
# Best score: 2234.0, Current score: 2234.0, Temperature: 668.9717585696801
# Best score: 2234.0, Current score: 2234.0, Temperature: 662.2820409839833
# Best score: 2234.0, Current score: 2234.0, Temperature: 655.6592205741434
# Best score: 2234.0, Current score: 2234.0, Temperature: 649.102628368402
# Best score: 2234.0, Current score: 2234.0, Temperature: 642.6116020847179
# Best score: 2234.0, Current score: 2234.0, Temperature: 636.1854860638707
# Best score: 2234.0, Current score: 2234.0, Temperature: 629.823631203232
# Best score: 2234.0, Current score: 2234.0, Temperature: 623.5253948911997
# Best score: 2234.0, Current score: 2234.0, Temperature: 617.2901409422876
# Best score: 2234.0, Current score: 2234.0, Temperature: 611.1172395328647
# Best score: 2234.0, Current score: 2234.0, Temperature: 605.006067137536
# Best score: 2234.0, Current score: 2234.0, Temperature: 598.9560064661606
# Best score: 2234.0, Current score: 2234.0, Temperature: 592.966446401499
# Best score: 2234.0, Current score: 2234.0, Temperature: 587.036781937484
# Best score: 2234.0, Current score: 2234.0, Temperature: 581.1664141181092
# Best score: 2234.0, Current score: 2234.0, Temperature: 575.3547499769281
# Best score: 2234.0, Current score: 2234.0, Temperature: 569.6012024771588
# Best score: 2234.0, Current score: 2234.0, Temperature: 563.9051904523873
# Best score: 2234.0, Current score: 2234.0, Temperature: 558.2661385478634
# Best score: 2234.0, Current score: 2234.0, Temperature: 552.6834771623847
# Best score: 2234.0, Current score: 2234.0, Temperature: 547.1566423907609
# Best score: 2234.0, Current score: 2234.0, Temperature: 541.6850759668533
# Best score: 2234.0, Current score: 2234.0, Temperature: 536.2682252071847
# Best score: 2234.0, Current score: 2234.0, Temperature: 530.9055429551129
# Best score: 2234.0, Current score: 2234.0, Temperature: 525.5964875255618
# Best score: 2234.0, Current score: 2234.0, Temperature: 520.3405226503062
# Best score: 2234.0, Current score: 2234.0, Temperature: 515.1371174238031
# Best score: 2234.0, Current score: 2234.0, Temperature: 509.9857462495651
# Best score: 2234.0, Current score: 2234.0, Temperature: 504.88588878706946
# Best score: 2234.0, Current score: 2234.0, Temperature: 499.83702989919874
# Best score: 2234.0, Current score: 2234.0, Temperature: 494.83865960020677
# Best score: 2234.0, Current score: 2234.0, Temperature: 489.8902730042047
# Best score: 2234.0, Current score: 2234.0, Temperature: 484.99137027416265
# Best score: 2234.0, Current score: 2234.0, Temperature: 480.14145657142103
# Best score: 2234.0, Current score: 2234.0, Temperature: 475.34004200570683
# Best score: 2234.0, Current score: 2234.0, Temperature: 470.5866415856498
# Best score: 2234.0, Current score: 2234.0, Temperature: 465.88077516979325
# Best score: 2234.0, Current score: 2234.0, Temperature: 461.2219674180953
# Best score: 2234.0, Current score: 2234.0, Temperature: 456.60974774391434
# Best score: 2234.0, Current score: 2234.0, Temperature: 452.0436502664752
# Best score: 2234.0, Current score: 2234.0, Temperature: 447.5232137638104
# Best score: 2234.0, Current score: 2234.0, Temperature: 443.0479816261723
# Best score: 2234.0, Current score: 2234.0, Temperature: 438.6175018099106
# Best score: 2234.0, Current score: 2234.0, Temperature: 434.2313267918115
# Best score: 2234.0, Current score: 2234.0, Temperature: 429.88901352389337
# Best score: 2234.0, Current score: 2234.0, Temperature: 425.59012338865443
# Best score: 2234.0, Current score: 2234.0, Temperature: 421.3342221547679
# Best score: 2234.0, Current score: 2234.0, Temperature: 417.1208799332202
# Best score: 2234.0, Current score: 2234.0, Temperature: 412.949671133888
# Best score: 2234.0, Current score: 2234.0, Temperature: 408.8201744225491
# Best score: 2234.0, Current score: 2234.0, Temperature: 404.7319726783236
# Best score: 2234.0, Current score: 2234.0, Temperature: 400.68465295154033
# Best score: 2234.0, Current score: 2234.0, Temperature: 396.6778064220249
# Best score: 2234.0, Current score: 2234.0, Temperature: 392.71102835780465
# Best score: 2234.0, Current score: 2234.0, Temperature: 388.7839180742266
# Best score: 2234.0, Current score: 2234.0, Temperature: 384.89607889348434
# Best score: 2234.0, Current score: 2234.0, Temperature: 381.0471181045495
# Best score: 2234.0, Current score: 2234.0, Temperature: 377.236646923504
# Best score: 2234.0, Current score: 2234.0, Temperature: 373.46428045426893
# Best score: 2234.0, Current score: 2234.0, Temperature: 369.7296376497262
# Best score: 2234.0, Current score: 2234.0, Temperature: 366.03234127322895
# Best score: 2234.0, Current score: 2234.0, Temperature: 362.37201786049667
# Best score: 2234.0, Current score: 2234.0, Temperature: 358.7482976818917
# Best score: 2234.0, Current score: 2234.0, Temperature: 355.16081470507277
# Best score: 2234.0, Current score: 2234.0, Temperature: 351.60920655802204
# Best score: 2234.0, Current score: 2234.0, Temperature: 348.0931144924418
# Best score: 2234.0, Current score: 2234.0, Temperature: 344.61218334751743
# Best score: 2234.0, Current score: 2234.0, Temperature: 341.16606151404227
# Best score: 2234.0, Current score: 2234.0, Temperature: 337.75440089890185
# Best score: 2234.0, Current score: 2234.0, Temperature: 334.3768568899128
# Best score: 2234.0, Current score: 2234.0, Temperature: 331.0330883210137
# Best score: 2234.0, Current score: 2234.0, Temperature: 327.7227574378035
# Best score: 2234.0, Current score: 2234.0, Temperature: 324.44552986342546
# Best score: 2234.0, Current score: 2234.0, Temperature: 321.2010745647912
# Best score: 2234.0, Current score: 2234.0, Temperature: 317.9890638191433
# Best score: 2234.0, Current score: 2234.0, Temperature: 314.8091731809519
# Best score: 2234.0, Current score: 2234.0, Temperature: 311.6610814491424
# Best score: 2234.0, Current score: 2234.0, Temperature: 308.54447063465096
# Best score: 2234.0, Current score: 2234.0, Temperature: 305.45902592830447
# Best score: 2234.0, Current score: 2234.0, Temperature: 302.40443566902144
# Best score: 2234.0, Current score: 2234.0, Temperature: 299.3803913123312
# Best score: 2234.0, Current score: 2234.0, Temperature: 296.3865873992079
# Best score: 2234.0, Current score: 2234.0, Temperature: 293.4227215252158
# Best score: 2234.0, Current score: 2234.0, Temperature: 290.48849430996364
# Best score: 2234.0, Current score: 2234.0, Temperature: 287.583609366864
# Best score: 2234.0, Current score: 2234.0, Temperature: 284.70777327319536
# Best score: 2234.0, Current score: 2234.0, Temperature: 281.8606955404634
# Best score: 2234.0, Current score: 2234.0, Temperature: 279.04208858505876
# Best score: 2234.0, Current score: 2234.0, Temperature: 276.25166769920816
# Best score: 2234.0, Current score: 2234.0, Temperature: 273.48915102221605
# Best score: 2234.0, Current score: 2234.0, Temperature: 270.7542595119939
# Best score: 2234.0, Current score: 2234.0, Temperature: 268.04671691687395
# Best score: 2234.0, Current score: 2234.0, Temperature: 265.3662497477052
# Best score: 2234.0, Current score: 2234.0, Temperature: 262.7125872502281
# Best score: 2234.0, Current score: 2234.0, Temperature: 260.08546137772584
# Best score: 2234.0, Current score: 2234.0, Temperature: 257.4846067639486
# Best score: 2234.0, Current score: 2234.0, Temperature: 254.9097606963091
# Best score: 2234.0, Current score: 2234.0, Temperature: 252.360663089346
# Best score: 2234.0, Current score: 2234.0, Temperature: 249.83705645845254
# Best score: 2234.0, Current score: 2234.0, Temperature: 247.33868589386802
# Best score: 2234.0, Current score: 2234.0, Temperature: 244.86529903492934
# Best score: 2234.0, Current score: 2234.0, Temperature: 242.41664604458003
# Best score: 2234.0, Current score: 2234.0, Temperature: 239.99247958413423
# Best score: 2234.0, Current score: 2234.0, Temperature: 237.5925547882929
# Best score: 2234.0, Current score: 2234.0, Temperature: 235.21662924040996
# Best score: 2234.0, Current score: 2234.0, Temperature: 232.86446294800587
# Best score: 2234.0, Current score: 2234.0, Temperature: 230.5358183185258
# Best score: 2234.0, Current score: 2234.0, Temperature: 228.23046013534054
# Best score: 2234.0, Current score: 2234.0, Temperature: 225.94815553398712
# Best score: 2234.0, Current score: 2234.0, Temperature: 223.68867397864724
# Best score: 2234.0, Current score: 2234.0, Temperature: 221.45178723886076
# Best score: 2234.0, Current score: 2234.0, Temperature: 219.23726936647216
# Best score: 2234.0, Current score: 2234.0, Temperature: 217.04489667280743
# Best score: 2234.0, Current score: 2234.0, Temperature: 214.87444770607934
# Best score: 2234.0, Current score: 2234.0, Temperature: 212.72570322901854
# Best score: 2234.0, Current score: 2234.0, Temperature: 210.59844619672836
# Best score: 2234.0, Current score: 2234.0, Temperature: 208.49246173476106
# Best score: 2234.0, Current score: 2234.0, Temperature: 206.40753711741345
# Best score: 2234.0, Current score: 2234.0, Temperature: 204.3434617462393
# Best score: 2234.0, Current score: 2234.0, Temperature: 202.30002712877692
# Best score: 2234.0, Current score: 2234.0, Temperature: 200.27702685748915
# Best score: 2234.0, Current score: 2234.0, Temperature: 198.27425658891426
# Best score: 2234.0, Current score: 2234.0, Temperature: 196.29151402302512
# Best score: 2234.0, Current score: 2234.0, Temperature: 194.32859888279486
# Best score: 2234.0, Current score: 2234.0, Temperature: 192.38531289396693
# Best score: 2234.0, Current score: 2234.0, Temperature: 190.46145976502726
# Best score: 2234.0, Current score: 2234.0, Temperature: 188.556845167377
# Best score: 2234.0, Current score: 2234.0, Temperature: 186.67127671570321
# Best score: 2234.0, Current score: 2234.0, Temperature: 184.8045639485462
# Best score: 2234.0, Current score: 2234.0, Temperature: 182.95651830906073
# Best score: 2234.0, Current score: 2234.0, Temperature: 181.12695312597012
# Best score: 2234.0, Current score: 2234.0, Temperature: 179.3156835947104
# Best score: 2234.0, Current score: 2234.0, Temperature: 177.5225267587633
# Best score: 2234.0, Current score: 2234.0, Temperature: 175.74730149117565
# Best score: 2234.0, Current score: 2234.0, Temperature: 173.98982847626388
# Best score: 2234.0, Current score: 2234.0, Temperature: 172.24993019150125
# Best score: 2234.0, Current score: 2234.0, Temperature: 170.52743088958624
# Best score: 2234.0, Current score: 2234.0, Temperature: 168.82215658069038
# Best score: 2234.0, Current score: 2234.0, Temperature: 167.13393501488346
# Best score: 2234.0, Current score: 2234.0, Temperature: 165.46259566473464
# Best score: 2234.0, Current score: 2234.0, Temperature: 163.80796970808728
# Best score: 2234.0, Current score: 2234.0, Temperature: 162.1698900110064
# Best score: 2234.0, Current score: 2234.0, Temperature: 160.54819111089634
# Best score: 2234.0, Current score: 2234.0, Temperature: 158.94270919978737
# Best score: 2234.0, Current score: 2234.0, Temperature: 157.3532821077895
# Best score: 2234.0, Current score: 2234.0, Temperature: 155.77974928671162
# Best score: 2234.0, Current score: 2234.0, Temperature: 154.2219517938445
# Best score: 2234.0, Current score: 2234.0, Temperature: 152.67973227590608
# Best score: 2234.0, Current score: 2234.0, Temperature: 151.15293495314702
# Best score: 2234.0, Current score: 2234.0, Temperature: 149.64140560361557
# Best score: 2234.0, Current score: 2234.0, Temperature: 148.14499154757942
# Best score: 2234.0, Current score: 2234.0, Temperature: 146.66354163210363
# Best score: 2234.0, Current score: 2234.0, Temperature: 145.1969062157826
# Best score: 2234.0, Current score: 2234.0, Temperature: 143.7449371536248
# Best score: 2234.0, Current score: 2234.0, Temperature: 142.30748778208854
# Best score: 2234.0, Current score: 2234.0, Temperature: 140.88441290426766
# Best score: 2234.0, Current score: 2234.0, Temperature: 139.47556877522499
# Best score: 2234.0, Current score: 2234.0, Temperature: 138.08081308747273
# Best score: 2234.0, Current score: 2234.0, Temperature: 136.700004956598
# Best score: 2234.0, Current score: 2234.0, Temperature: 135.33300490703203
# Best score: 2234.0, Current score: 2234.0, Temperature: 133.97967485796173
# Best score: 2234.0, Current score: 2234.0, Temperature: 132.6398781093821
# Best score: 2234.0, Current score: 2234.0, Temperature: 131.31347932828828
# Best score: 2234.0, Current score: 2234.0, Temperature: 130.0003445350054
# Best score: 2234.0, Current score: 2234.0, Temperature: 128.70034108965535
# Best score: 2234.0, Current score: 2234.0, Temperature: 127.4133376787588
# Best score: 2234.0, Current score: 2234.0, Temperature: 126.1392043019712
# Best score: 2234.0, Current score: 2234.0, Temperature: 124.8778122589515
# Best score: 2234.0, Current score: 2234.0, Temperature: 123.62903413636198
# Best score: 2234.0, Current score: 2234.0, Temperature: 122.39274379499835
# Best score: 2234.0, Current score: 2234.0, Temperature: 121.16881635704837
# Best score: 2234.0, Current score: 2234.0, Temperature: 119.95712819347789
# Best score: 2234.0, Current score: 2234.0, Temperature: 118.7575569115431
# Best score: 2234.0, Current score: 2234.0, Temperature: 117.56998134242767
# Best score: 2234.0, Current score: 2234.0, Temperature: 116.3942815290034
# Best score: 2234.0, Current score: 2234.0, Temperature: 115.23033871371337
# Best score: 2234.0, Current score: 2234.0, Temperature: 114.07803532657623
# Best score: 2234.0, Current score: 2234.0, Temperature: 112.93725497331046
# Best score: 2234.0, Current score: 2234.0, Temperature: 111.80788242357735
# Best score: 2234.0, Current score: 2234.0, Temperature: 110.68980359934157
# Best score: 2234.0, Current score: 2234.0, Temperature: 109.58290556334816
# Best score: 2234.0, Current score: 2234.0, Temperature: 108.48707650771468
# Best score: 2234.0, Current score: 2234.0, Temperature: 107.40220574263753
# Best score: 2234.0, Current score: 2234.0, Temperature: 106.32818368521116
# Best score: 2234.0, Current score: 2234.0, Temperature: 105.26490184835905
# Best score: 2234.0, Current score: 2234.0, Temperature: 104.21225282987545
# Best score: 2234.0, Current score: 2234.0, Temperature: 103.17013030157669
# Best score: 2234.0, Current score: 2234.0, Temperature: 102.13842899856093
# Best score: 2234.0, Current score: 2234.0, Temperature: 101.11704470857532
# Best score: 2234.0, Current score: 2234.0, Temperature: 100.10587426148956
# Best score: 2234.0, Current score: 2234.0, Temperature: 99.10481551887466
# Best score: 2234.0, Current score: 2234.0, Temperature: 98.11376736368591
# Best score: 2234.0, Current score: 2234.0, Temperature: 97.13262969004904
# Best score: 2234.0, Current score: 2234.0, Temperature: 96.16130339314856
# Best score: 2234.0, Current score: 2234.0, Temperature: 95.19969035921707
# Best score: 2234.0, Current score: 2234.0, Temperature: 94.2476934556249
# Best score: 2234.0, Current score: 2234.0, Temperature: 93.30521652106864
# Best score: 2234.0, Current score: 2234.0, Temperature: 92.37216435585796
# Best score: 2234.0, Current score: 2234.0, Temperature: 91.44844271229938
# Best score: 2234.0, Current score: 2234.0, Temperature: 90.53395828517638
# Best score: 2234.0, Current score: 2234.0, Temperature: 89.62861870232462
# Best score: 2234.0, Current score: 2234.0, Temperature: 88.73233251530137
# Best score: 2234.0, Current score: 2234.0, Temperature: 87.84500919014835
# Best score: 2234.0, Current score: 2234.0, Temperature: 86.96655909824686
# Best score: 2234.0, Current score: 2234.0, Temperature: 86.0968935072644
# Best score: 2234.0, Current score: 2234.0, Temperature: 85.23592457219175
# Best score: 2234.0, Current score: 2234.0, Temperature: 84.38356532646984
# Best score: 2234.0, Current score: 2234.0, Temperature: 83.53972967320513
# Best score: 2234.0, Current score: 2234.0, Temperature: 82.70433237647308
# Best score: 2234.0, Current score: 2234.0, Temperature: 81.87728905270835
# Best score: 2234.0, Current score: 2234.0, Temperature: 81.05851616218126
# Best score: 2234.0, Current score: 2234.0, Temperature: 80.24793100055945
# Best score: 2234.0, Current score: 2234.0, Temperature: 79.44545169055385
# Best score: 2234.0, Current score: 2234.0, Temperature: 78.6509971736483
# Best score: 2234.0, Current score: 2234.0, Temperature: 77.86448720191183
# Best score: 2234.0, Current score: 2234.0, Temperature: 77.08584232989271
# Best score: 2234.0, Current score: 2234.0, Temperature: 76.31498390659378
# Best score: 2234.0, Current score: 2234.0, Temperature: 75.55183406752785
# Best score: 2234.0, Current score: 2234.0, Temperature: 74.79631572685257
# Best score: 2234.0, Current score: 2234.0, Temperature: 74.04835256958404
# Best score: 2234.0, Current score: 2234.0, Temperature: 73.3078690438882
# Best score: 2234.0, Current score: 2234.0, Temperature: 72.57479035344932
# Best score: 2234.0, Current score: 2234.0, Temperature: 71.84904244991482
# Best score: 2234.0, Current score: 2234.0, Temperature: 71.13055202541567
# Best score: 2234.0, Current score: 2234.0, Temperature: 70.41924650516151
# Best score: 2234.0, Current score: 2234.0, Temperature: 69.71505404010989
# Best score: 2234.0, Current score: 2234.0, Temperature: 69.0179034997088
# Best score: 2234.0, Current score: 2234.0, Temperature: 68.32772446471171
# Best score: 2234.0, Current score: 2234.0, Temperature: 67.64444722006459
# Best score: 2234.0, Current score: 2234.0, Temperature: 66.96800274786395
# Best score: 2234.0, Current score: 2234.0, Temperature: 66.29832272038531
# Best score: 2234.0, Current score: 2234.0, Temperature: 65.63533949318146
# Best score: 2234.0, Current score: 2234.0, Temperature: 64.97898609824965
# Best score: 2234.0, Current score: 2234.0, Temperature: 64.32919623726715
# Best score: 2234.0, Current score: 2234.0, Temperature: 63.68590427489448
# Best score: 2234.0, Current score: 2234.0, Temperature: 63.04904523214554
# Best score: 2234.0, Current score: 2234.0, Temperature: 62.418554779824085
# Best score: 2234.0, Current score: 2234.0, Temperature: 61.79436923202584
# Best score: 2234.0, Current score: 2234.0, Temperature: 61.17642553970558
# Best score: 2234.0, Current score: 2234.0, Temperature: 60.56466128430853
# Best score: 2234.0, Current score: 2234.0, Temperature: 59.95901467146544
# Best score: 2234.0, Current score: 2234.0, Temperature: 59.359424524750786
# Best score: 2234.0, Current score: 2234.0, Temperature: 58.76583027950328
# Best score: 2234.0, Current score: 2234.0, Temperature: 58.17817197670824
# Best score: 2234.0, Current score: 2234.0, Temperature: 57.596390256941156
# Best score: 2234.0, Current score: 2234.0, Temperature: 57.02042635437174
# Best score: 2234.0, Current score: 2234.0, Temperature: 56.45022209082803
# Best score: 2234.0, Current score: 2234.0, Temperature: 55.88571986991975
# Best score: 2234.0, Current score: 2234.0, Temperature: 55.326862671220546
# Best score: 2234.0, Current score: 2234.0, Temperature: 54.77359404450834
# Best score: 2234.0, Current score: 2234.0, Temperature: 54.225858104063256
# Best score: 2234.0, Current score: 2234.0, Temperature: 53.68359952302262
# Best score: 2234.0, Current score: 2234.0, Temperature: 53.146763527792395
# Best score: 2234.0, Current score: 2234.0, Temperature: 52.61529589251447
# Best score: 2234.0, Current score: 2234.0, Temperature: 52.08914293358932
# Best score: 2234.0, Current score: 2234.0, Temperature: 51.56825150425343
# Best score: 2234.0, Current score: 2234.0, Temperature: 51.0525689892109
# Best score: 2234.0, Current score: 2234.0, Temperature: 50.542043299318784
# Best score: 2234.0, Current score: 2234.0, Temperature: 50.036622866325594
# Best score: 2234.0, Current score: 2234.0, Temperature: 49.53625663766234
# Best score: 2234.0, Current score: 2234.0, Temperature: 49.04089407128572
# Best score: 2234.0, Current score: 2234.0, Temperature: 48.55048513057286
# Best score: 2234.0, Current score: 2234.0, Temperature: 48.06498027926713
# Best score: 2234.0, Current score: 2234.0, Temperature: 47.58433047647446
# Best score: 2234.0, Current score: 2234.0, Temperature: 47.10848717170972
# Best score: 2234.0, Current score: 2234.0, Temperature: 46.63740229999262
# Best score: 2234.0, Current score: 2234.0, Temperature: 46.17102827699269
# Best score: 2234.0, Current score: 2234.0, Temperature: 45.709317994222765
# Best score: 2234.0, Current score: 2234.0, Temperature: 45.25222481428054
# Best score: 2234.0, Current score: 2234.0, Temperature: 44.79970256613773
# Best score: 2234.0, Current score: 2234.0, Temperature: 44.35170554047635
# Best score: 2234.0, Current score: 2234.0, Temperature: 43.90818848507159
# Best score: 2234.0, Current score: 2234.0, Temperature: 43.469106600220876
# Best score: 2234.0, Current score: 2234.0, Temperature: 43.03441553421867
# Best score: 2234.0, Current score: 2234.0, Temperature: 42.604071378876476
# Best score: 2234.0, Current score: 2234.0, Temperature: 42.17803066508771
# Best score: 2234.0, Current score: 2234.0, Temperature: 41.75625035843683
# Best score: 2234.0, Current score: 2234.0, Temperature: 41.33868785485246
# Best score: 2234.0, Current score: 2234.0, Temperature: 40.92530097630394
# Best score: 2234.0, Current score: 2234.0, Temperature: 40.516047966540896
# Best score: 2234.0, Current score: 2234.0, Temperature: 40.110887486875484
# Best score: 2234.0, Current score: 2234.0, Temperature: 39.70977861200673
# Best score: 2234.0, Current score: 2234.0, Temperature: 39.31268082588666
# Best score: 2234.0, Current score: 2234.0, Temperature: 38.91955401762779
# Best score: 2234.0, Current score: 2234.0, Temperature: 38.53035847745151
# Best score: 2234.0, Current score: 2234.0, Temperature: 38.145054892676995
# Best score: 2234.0, Current score: 2234.0, Temperature: 37.763604343750224
# Best score: 2234.0, Current score: 2234.0, Temperature: 37.38596830031272
# Best score: 2234.0, Current score: 2234.0, Temperature: 37.01210861730959
# Best score: 2234.0, Current score: 2234.0, Temperature: 36.6419875311365
# Best score: 2234.0, Current score: 2234.0, Temperature: 36.275567655825135
# Best score: 2234.0, Current score: 2234.0, Temperature: 35.912811979266884
# Best score: 2234.0, Current score: 2234.0, Temperature: 35.55368385947421
# Best score: 2234.0, Current score: 2234.0, Temperature: 35.19814702087947
# Best score: 2234.0, Current score: 2234.0, Temperature: 34.84616555067067
# Best score: 2234.0, Current score: 2234.0, Temperature: 34.497703895163966
# Best score: 2234.0, Current score: 2234.0, Temperature: 34.152726856212325
# Best score: 2234.0, Current score: 2234.0, Temperature: 33.8111995876502
# Best score: 2234.0, Current score: 2234.0, Temperature: 33.4730875917737
# Best score: 2234.0, Current score: 2234.0, Temperature: 33.13835671585596
# Best score: 2234.0, Current score: 2234.0, Temperature: 32.8069731486974
# Best score: 2234.0, Current score: 2234.0, Temperature: 32.478903417210425
# Best score: 2234.0, Current score: 2234.0, Temperature: 32.15411438303832
# Best score: 2234.0, Current score: 2234.0, Temperature: 31.832573239207935
# Best score: 2234.0, Current score: 2234.0, Temperature: 31.514247506815856
# Best score: 2234.0, Current score: 2234.0, Temperature: 31.1991050317477
# Best score: 2234.0, Current score: 2234.0, Temperature: 30.887113981430222
# Best score: 2234.0, Current score: 2234.0, Temperature: 30.578242841615918
# Best score: 2234.0, Current score: 2234.0, Temperature: 30.27246041319976
# Best score: 2234.0, Current score: 2234.0, Temperature: 29.96973580906776
# Best score: 2234.0, Current score: 2234.0, Temperature: 29.67003845097708
# Best score: 2234.0, Current score: 2234.0, Temperature: 29.373338066467312
# Best score: 2234.0, Current score: 2234.0, Temperature: 29.07960468580264
# Best score: 2234.0, Current score: 2234.0, Temperature: 28.788808638944612
# Best score: 2234.0, Current score: 2234.0, Temperature: 28.500920552555165
# Best score: 2234.0, Current score: 2234.0, Temperature: 28.215911347029614
# Best score: 2234.0, Current score: 2234.0, Temperature: 27.933752233559318
# Best score: 2234.0, Current score: 2234.0, Temperature: 27.654414711223723
# Best score: 2234.0, Current score: 2234.0, Temperature: 27.377870564111486
# Best score: 2234.0, Current score: 2234.0, Temperature: 27.104091858470373
# Best score: 2234.0, Current score: 2234.0, Temperature: 26.83305093988567
# Best score: 2234.0, Current score: 2234.0, Temperature: 26.564720430486812
# Best score: 2234.0, Current score: 2234.0, Temperature: 26.299073226181942
# Best score: 2234.0, Current score: 2234.0, Temperature: 26.036082493920123
# Best score: 2234.0, Current score: 2234.0, Temperature: 25.77572166898092
# Best score: 2234.0, Current score: 2234.0, Temperature: 25.51796445229111
# Best score: 2234.0, Current score: 2234.0, Temperature: 25.2627848077682
# Best score: 2234.0, Current score: 2234.0, Temperature: 25.010156959690516
# Best score: 2234.0, Current score: 2234.0, Temperature: 24.760055390093612
# Best score: 2234.0, Current score: 2234.0, Temperature: 24.512454836192674
# Best score: 2234.0, Current score: 2234.0, Temperature: 24.26733028783075
# Best score: 2234.0, Current score: 2234.0, Temperature: 24.02465698495244
# Best score: 2234.0, Current score: 2234.0, Temperature: 23.784410415102915
# Best score: 2234.0, Current score: 2234.0, Temperature: 23.546566310951885
# Best score: 2234.0, Current score: 2234.0, Temperature: 23.311100647842366
# Best score: 2234.0, Current score: 2234.0, Temperature: 23.077989641363942
# Best score: 2234.0, Current score: 2234.0, Temperature: 22.8472097449503
# Best score: 2234.0, Current score: 2234.0, Temperature: 22.618737647500797
# Best score: 2234.0, Current score: 2234.0, Temperature: 22.39255027102579
# Best score: 2234.0, Current score: 2234.0, Temperature: 22.16862476831553
# Best score: 2234.0, Current score: 2234.0, Temperature: 21.946938520632376
# Best score: 2234.0, Current score: 2234.0, Temperature: 21.727469135426052
# Best score: 2234.0, Current score: 2234.0, Temperature: 21.51019444407179
# Best score: 2234.0, Current score: 2234.0, Temperature: 21.29509249963107
# Best score: 2234.0, Current score: 2234.0, Temperature: 21.08214157463476
# Best score: 2234.0, Current score: 2234.0, Temperature: 20.871320158888413
# Best score: 2234.0, Current score: 2234.0, Temperature: 20.662606957299527
# Best score: 2234.0, Current score: 2234.0, Temperature: 20.455980887726533
# Best score: 2234.0, Current score: 2234.0, Temperature: 20.251421078849265
# Best score: 2234.0, Current score: 2234.0, Temperature: 20.048906868060772
# Best score: 2234.0, Current score: 2234.0, Temperature: 19.848417799380165
# Best score: 2234.0, Current score: 2234.0, Temperature: 19.649933621386364
# Best score: 2234.0, Current score: 2234.0, Temperature: 19.4534342851725
# Best score: 2234.0, Current score: 2234.0, Temperature: 19.258899942320774
# Best score: 2234.0, Current score: 2234.0, Temperature: 19.066310942897566
# Best score: 2234.0, Current score: 2234.0, Temperature: 18.87564783346859
# Best score: 2234.0, Current score: 2234.0, Temperature: 18.686891355133906
# Best score: 2234.0, Current score: 2234.0, Temperature: 18.500022441582566
# Best score: 2234.0, Current score: 2234.0, Temperature: 18.31502221716674
# Best score: 2234.0, Current score: 2234.0, Temperature: 18.13187199499507
# Best score: 2234.0, Current score: 2234.0, Temperature: 17.95055327504512
# Best score: 2234.0, Current score: 2234.0, Temperature: 17.77104774229467
# Best score: 2234.0, Current score: 2234.0, Temperature: 17.59333726487172
# Best score: 2234.0, Current score: 2234.0, Temperature: 17.417403892223003
# Best score: 2234.0, Current score: 2234.0, Temperature: 17.24322985330077
# Best score: 2234.0, Current score: 2234.0, Temperature: 17.070797554767765
# Best score: 2234.0, Current score: 2234.0, Temperature: 16.900089579220086
# Best score: 2234.0, Current score: 2234.0, Temperature: 16.731088683427885
# Best score: 2234.0, Current score: 2234.0, Temperature: 16.563777796593605
# Best score: 2234.0, Current score: 2234.0, Temperature: 16.398140018627668
# Best score: 2234.0, Current score: 2234.0, Temperature: 16.23415861844139
# Best score: 2234.0, Current score: 2234.0, Temperature: 16.071817032256977
# Best score: 2234.0, Current score: 2234.0, Temperature: 15.911098861934407
# Best score: 2234.0, Current score: 2234.0, Temperature: 15.751987873315063
# Best score: 2234.0, Current score: 2234.0, Temperature: 15.594467994581912
# Best score: 2234.0, Current score: 2234.0, Temperature: 15.438523314636093
# Best score: 2234.0, Current score: 2234.0, Temperature: 15.284138081489733
# Best score: 2234.0, Current score: 2234.0, Temperature: 15.131296700674834
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.979983733668085
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.830183896331404
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.681882057368089
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.535063236794407
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.389712604426464
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.245815478382198
# Best score: 2234.0, Current score: 2234.0, Temperature: 14.103357323598376
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.962323750362392
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.822700512858768
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.68447350773018
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.547628772652878
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.412152484926349
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.278030960077086
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.145250650476315
# Best score: 2234.0, Current score: 2234.0, Temperature: 13.013798143971552
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.883660162531838
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.75482356090652
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.627275325297454
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.501002572044479
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.375992546324035
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.252232620860795
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.129710294652186
# Best score: 2234.0, Current score: 2234.0, Temperature: 12.008413191705664
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.888329059788607
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.769445769190721
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.651751311498813
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.535233798383825
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.419881460399987
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.305682645795986
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.192625819338026
# Best score: 2234.0, Current score: 2234.0, Temperature: 11.080699561144646
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.9698925655332
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.860193639877869
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.75159170347909
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.644075786444299
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.537635028579857
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.432258678294058
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.327936091511118
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.224656730596006
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.122410163290047
# Best score: 2234.0, Current score: 2234.0, Temperature: 10.021186061657145
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.920974201040574
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.821764459030168
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.723546814439867
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.626311346295468
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.530048232832513
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.434747750504188
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.340400272999146
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.246996270269154
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.154526307566462
# Best score: 2234.0, Current score: 2234.0, Temperature: 9.062981044490797
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.97235123404589
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.88262772170543
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.793801444488377
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.705863430043493
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.618804795743058
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.532616747785628
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.447290580307772
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.362817674504694
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.279189497759647
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.196397602782051
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.11443362675423
# Best score: 2234.0, Current score: 2234.0, Temperature: 8.033289290486689
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.952956397581822
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.873426833606004
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.794692565269944
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.716745639617245
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.639578183221072
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.563182401388861
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.487550577374972
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.412675071601223
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.33854832088521
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.265162837676358
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.192511209299594
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.120586097206599
# Best score: 2234.0, Current score: 2234.0, Temperature: 7.049380236234533
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.978886433872187
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.909097569533465
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.8400065938381305
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.771606527899749
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.703890462620752
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.636851557994544
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.570483042414598
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.504778211990453
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.439730429870548
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.375333125571842
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.311579794316124
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.248463996372963
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.185979356409233
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.124119562845141
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.0628783672166895
# Best score: 2234.0, Current score: 2234.0, Temperature: 6.002249583544523
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.942227087709077
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.882804816831986
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.823976768663666
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.76573700097703
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.7080796309672595
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.650998834657587
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.594488846311011
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.5385439578479
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.483158518269422
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.428326933086727
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.3740436637558595
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.320303227118301
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.267100194847118
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.214429192898647
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.16228490096966
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.110662051959964
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.059555431440364
# Best score: 2234.0, Current score: 2234.0, Temperature: 5.00895987712596
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.9588702783547
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.909281575571153
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.860188759815442
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.811586872217287
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.763471003495114
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.715836293460163
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.668677930525561
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.621991151220306
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.575771239708103
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.530013527311022
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.484713392037912
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.439866258117532
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.395467595536357
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.351512919580993
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.307997790385183
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.264917812481332
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.222268634356518
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.180045948012953
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.1382454885328235
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.096863033647495
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.0558944033110205
# Best score: 2234.0, Current score: 2234.0, Temperature: 4.01533545927791
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.975182104685131
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.9354302836382797
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.8960759808018968
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.8571152209938777
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.8185440687839387
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.7803586280960992
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.7425550418151383
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.705129491396987
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.668078196483017
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.6313974145181867
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.5950834403730045
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.5591326059692743
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.5235412799095815
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.4883058671104856
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.4534228084393805
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.4188885803549867
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.3846996945514367
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.3508526976059225
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.3173441706298634
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.2841707289235647
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.251329021634329
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.218815731417986
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.186627574103806
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.154761298362768
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.1232136853791403
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.091981548525349
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.0610617330400953
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.0304511157096945
# Best score: 2234.0, Current score: 2234.0, Temperature: 3.0001466045525977
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.9701451385070716
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.9404436871220008
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.9110392502507807
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.8819288577482727
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.85310956917079
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.824578473479082
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.796332688744291
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.768369361856848
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.7406856682382794
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.7132788115558966
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.6861460234403376
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.6592845632059343
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.632691717573875
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.606364800398136
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.5803011523941546
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.554498140870213
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.5289531594615107
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.5036636278668953
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.4786269915882264
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.453840721672344
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.4293023144556205
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.4050092913110643
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.380959198397954
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.3571496064139743
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.3335781103498348
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.3102423292463365
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.287139905953873
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.2642685068943345
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.2416258218253913
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.219209563607137
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.1970174679710657
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.175047293291355
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.1532968203584413
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.1317638521548568
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.110446213633308
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.089341751496975
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.0684483339820052
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.0477638506421854
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.0272862121357633
# Best score: 2234.0, Current score: 2234.0, Temperature: 2.0070133500144056
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.9869432165142615
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.9670737843491188
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.9474030465056276
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.9279290160405713
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.9086497258801656
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.889563228621364
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.8706675963351502
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.8519609203717986
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.8334413111680805
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.8151068980563998
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.7969558290758358
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.7789862707850774
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.7611964080772267
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.7435844439964543
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.7261485995564898
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.708887113560925
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.6917982424253157
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.6748802600010626
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.658131457401052
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.6415501428270414
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.6251346413987708
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.608883294984783
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.5927944620349352
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.576866517414586
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.5610978522404402
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.5454868737180358
# Best score: 2234.0, Current score: 2234.0, Temperature: 1.5300320049808556
# ...
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007819476506139887
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0077412817410784885
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007663868923667704
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007587230234431027
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007511357932086717
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007436244352765849
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007361881909238191
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007288263090145809
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00721538045924435
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007143226654651907
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007071794388105388
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.007001076444224335
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006931065679782091
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00686175502298427
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006793137472754427
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006725206098026883
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006657954037046614
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006591374496676148
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006525460751709386
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006460206144192292
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006395604082750369
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006331648041922865
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006268331561503636
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0062056482458886
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006143591763429714
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.006082155845795417
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0060213342873374626
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005961120944464088
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005901509735019447
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005842494637669253
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00578406969129256
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005726228994379634
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005668966704435838
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005612277037391479
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005556154267017565
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00550059272434739
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0054455867971039155
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005391130929132877
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005337219619841548
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005283847423643132
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0052310089494067005
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005178698859912633
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005126911871313507
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005075642752600372
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.005024886325074368
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004974637461823624
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004924891087205388
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004875642176333334
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004826885754570001
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004778616897024301
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004730830728054057
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004683522420773517
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0046366871965657815
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004590320324600124
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004544417121354122
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004498972950140581
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004453983220639175
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004409443388432783
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004365348954548456
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004321695465002971
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004278478510352942
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004235693725249412
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004193336787996918
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004151403420116949
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00410988938591578
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.004068790492056622
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0040281025871360555
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003987821561264695
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003947943345652048
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0039084639121955275
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003869379273073572
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003830685480342836
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003792378625539408
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0037544548392840138
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0037169102908911735
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0036797411879822615
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003642943776102439
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0036065143383414142
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003570449194958
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00353474470300842
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0034993972559783358
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0034644032834185525
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003429759250584367
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0033954616580785233
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003361507041497738
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0033278919710827606
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003294613051371933
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0032616669208582133
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003229050251649631
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003196759749133135
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0031647921516418033
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0031331442301253854
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0031018127878241317
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0030707946599458904
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0030400867133464314
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.003009685846212967
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0029795889877508373
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002949793097873329
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0029202951668945956
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00289109221522565
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0028621812930733933
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0028335594801426594
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002805223885341233
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0027771716464878205
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0027493999300229424
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002721905930722713
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0026946868714154857
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002667740002701331
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0026410626026743176
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0026146519766475744
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0025885054568810986
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0025626204023122875
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0025369941982891645
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0025116242563062727
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00248650801374321
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0024616429336057778
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.00243702650426972
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0024126562392270227
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0023885296768347527
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002364644380066405
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0023409979362657408
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0023175879569030835
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002294412077334053
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0022714679565607123
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0022487532769951053
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002226265744225154
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0022040030867829024
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0021819630559150732
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0021601434253559226
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0021385419911023633
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0021171565711913397
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0020959850054794262
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.002075025155424632
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0020542749038703853
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0020337321548316812
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0020133948332833646
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001993260884950531
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0019733282761010256
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001953594993340015
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001934059043406615
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001914718452972549
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0018955712684428235
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0018766155557583953
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0018578494002008115
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0018392709061988033
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0018208781971368153
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0018026694151654472
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0017846427210137926
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0017667962938036547
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0017491283308656183
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0017316370475569621
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0017143206770813926
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0016971774703105787
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0016802056956074728
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001663403638651398
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001646769602264884
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0016303019062422351
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0016139988871798129
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0015978588983080147
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0015818803093249345
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0015660615062316851
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0015504008911693683
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0015348968822576747
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001519547913435098
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0015043524343007469
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0014893089099577393
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001474415820858162
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0014596716626495804
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0014450749460230847
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0014306241965628538
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0014163179545972253
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001402154775051253
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0013881332273007405
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001374251895027733
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0013605093760774558
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0013469042823166812
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0013334352394935144
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0013201008870985793
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0013068998782275936
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012938308794453175
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012808925706508643
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012680836449443557
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012554028084949122
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001242848780409963
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012304202926058632
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012181160896798046
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0012059349287830065
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011938755794951765
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011819368237002247
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011701174554632225
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011584162809085902
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011468321180995043
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011353637969185092
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011240101589493241
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.001112770057359831
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0011016423567862326
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010906259332183702
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010797196738861865
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010689224771473246
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010582332523758513
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010476509198520927
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010371744106535718
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010268026665470362
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010165346398815658
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0010063692934827503
# Best score: 2234.0, Current score: 2234.0, Temperature: 0.0009963056005479227

# %%
sol.get_partitions()[0][0] == Feria(**sol.get_partitions()[0][0].__dict__)
# Out:
# True
